# %%
# %load_ext autoreload
# %autoreload 2

# %%
from models.cpmp_transformer_v2 import CPMPTransformer
from training.training import load_model

model_name = "v1"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver, StackMatrixAdapter, DefaultMovesAdapter

instance_file = "benchmarks/data5-5-1.dat"
max_steps = 100
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps, StackMatrixAdapter(), DefaultMovesAdapter())

print(eval)
# Out:
# (False, 100)

# %%
from solvers.model import ModelSolver, StackMatrixAdapter, DefaultMovesAdapter

folder = "benchmarks"
max_steps = 300
H = 7

solver = ModelSolver(model)
solved, steps = solver.solve_from_folder(folder, H, max_steps, StackMatrixAdapter(), DefaultMovesAdapter())

# %%
steps
# Out:
# [300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  291,
#  172,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300]
