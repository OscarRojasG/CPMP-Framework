# %%
# %load_ext autoreload
# %autoreload 2

# %%
from models.cpmp_transformer import CPMPTransformer
from training.training import load_model

model_name = "v1"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver

instance_file = "benchmarks/data5-5-8.dat"
max_steps = 50
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps)

print(eval)
# Out:
# 0 1
# 0 1
# 0 4
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# 3 0
# 0 3
# (5, 4)
