# %% [markdown]
# # Generación de datos de entrenamiento

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generación de instancias

# %%
from generation.instances import generate_instances, FullRandomGenerator

instance_generator = FullRandomGenerator(H=9, S=7, N=49, seed=42)
generate_instances(f"E7-7-RFull", instance_generator, 20000)

# %%
from generation.instances import generate_instances, RandomMovesGenerator

instance_generator = RandomMovesGenerator(H=9, S=7, N=49, r=100, seed=42)
generate_instances(f"E7-7-R100", instance_generator, 20000)

# %%
from generation.instances import generate_instances, RandomMovesGenerator

instance_generator = RandomMovesGenerator(H=9, S=7, N=49, r=50, seed=42)
generate_instances(f"E7-7-R50", instance_generator, 20000)

# %%
from generation.instances import generate_instances, RandomMovesGenerator

instance_generator = RandomMovesGenerator(H=9, S=7, N=49, r=20, seed=42)
generate_instances(f"E7-7-R20", instance_generator, 20000)

# %% [markdown]
# ## Generación de datos (SL)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4D3FAdapter
from generation.adapters.input.stack_features import StackFeatures3FAdapter
from generation.adapters.output import ActionAdapter

folders = ["E5-5-test"]
H = 7
max_steps = 50
input_adapter_config = (EnrichedLayoutAdapter, Layout4D3FAdapter, StackFeatures3FAdapter)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-test.data (Tamaño 100)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4D3FAdapter
from generation.adapters.input.stack_features import StackFeatures3FAdapter
from generation.adapters.output import ActionAdapter

folders = ["E5-5-R20", "E5-5-R50", "E5-5-R100", "E5-5-RFull"]
H = 7
max_steps = 50
input_adapter_config = (EnrichedLayoutAdapter, Layout4D3FAdapter, StackFeatures3FAdapter)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-R20.data (Tamaño 49454)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-R50.data (Tamaño 49985)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-R100.data (Tamaño 50000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-RFull.data (Tamaño 50000)

# %%
from generation.data import generate_data_sl
from generation.adapters.input import EnrichedLayoutAdapter, Layout4D3FAdapter
from generation.adapters.input.stack_features import StackFeatures3FAdapter
from generation.adapters.output import ActionAdapter

folders = ["E7-7-R20", "E7-7-R50", "E7-7-R100", "E7-7-RFull"]
H = 9
max_steps = 50
input_adapter_config = (EnrichedLayoutAdapter, Layout4D3FAdapter, StackFeatures3FAdapter)
output_adapter_config = (ActionAdapter, )
num_workers = 12
output_prefix = "actions"

generate_data_sl(folders, H, max_steps, input_adapter_config, output_adapter_config, num_workers, output_prefix)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-R20.data (Tamaño 19889)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-R50.data (Tamaño 20000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-R100.data (Tamaño 20000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-RFull.data (Tamaño 47)

# %%
## Generación de datasets por dificultad
## Costo = número de pasos

from preprocessing.dataset import generate_dataset

data_files = ["actions_E5-5-R20.data", "actions_E5-5-R50.data", "actions_E5-5-R100.data", "actions_E5-5-RFull.data"]
max_size = 10000
cost_intervals = [(1, 10), (11, 20), (21, 40)]

for min_cost, max_cost in cost_intervals:
    output_name = f"actions_E5-5-C{min_cost}-{max_cost}.data"
    generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-C1-10.data (Tamaño 10000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-C11-20.data (Tamaño 10000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E5-5-C21-40.data (Tamaño 10000)

# %%
## Generación de datasets por dificultad
## Costo = número de pasos

from preprocessing.dataset import generate_dataset

data_files = ["actions_E7-7-R20.data", "actions_E7-7-R50.data", "actions_E7-7-R100.data", "actions_E7-7-RFull.data"]
max_size = 10000
cost_intervals = [(1, 10), (11, 20), (21, 40)]

for min_cost, max_cost in cost_intervals:
    output_name = f"actions_E7-7-C{min_cost}-{max_cost}.data"
    generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
# Out:
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-C1-10.data (Tamaño 10000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-C11-20.data (Tamaño 10000)
# Dataset generado exitosamente en: /home/oscar/Escritorio/CPMP-Framework/data/actions_E7-7-C21-40.data (Tamaño 10000)

# %%
# Concatenamos los datasets
from preprocessing.dataset import generate_dataset

data_files = ["actions_E5-5-C1-10.data", "actions_E5-5-C11-20.data", "actions_E5-5-C21-40.data",
              "actions_E7-7-C1-10.data", "actions_E7-7-C11-20.data", "actions_E7-7-C21-40.data"]
output_name = "actions.data"

generate_dataset(data_files, output_name)
# Out:
# --- Verificando dimensiones antes de concatenar ---
#
# Revisando clave: 'input/L'
#   Archivo: actions_E5-5-C1-10.data | Shape: (10000, 10, 12, 3)
#   Archivo: actions_E5-5-C11-20.data | Shape: (10000, 10, 12, 3)
#   Archivo: actions_E5-5-C21-40.data | Shape: (10000, 10, 12, 3)
#   Archivo: actions_E7-7-C1-10.data | Shape: (10000, 10, 12, 3)
#   Archivo: actions_E7-7-C11-20.data | Shape: (10000, 10, 12, 3)
#   Archivo: actions_E7-7-C21-40.data | Shape: (10000, 10, 12, 3)
#
# Revisando clave: 'input/X'
#   Archivo: actions_E5-5-C1-10.data | Shape: (10000, 10, 3)
#   Archivo: actions_E5-5-C11-20.data | Shape: (10000, 10, 3)
#   Archivo: actions_E5-5-C21-40.data | Shape: (10000, 10, 3)
#   Archivo: actions_E7-7-C1-10.data | Shape: (10000, 10, 3)
#   Archivo: actions_E7-7-C11-20.data | Shape: (10000, 10, 3)
#   Archivo: actions_E7-7-C21-40.data | Shape: (10000, 10, 3)
#
# Revisando clave: 'input/S'
#   Archivo: actions_E5-5-C1-10.data | Shape: (10000,)
#   Archivo: actions_E5-5-C11-20.data | Shape: (10000,)
#   Archivo: actions_E5-5-C21-40.data | Shape: (10000,)
#   Archivo: actions_E7-7-C1-10.data | Shape: (10000,)
#   Archivo: actions_E7-7-C11-20.data | Shape: (10000,)
#   Archivo: actions_E7-7-C21-40.data | Shape: (10000,)
#
# Revisando clave: 'input/H'
#   Archivo: actions_E5-5-C1-10.data | Shape: (10000,)
#   Archivo: actions_E5-5-C11-20.data | Shape: (10000,)
#   Archivo: actions_E5-5-C21-40.data | Shape: (10000,)
#   Archivo: actions_E7-7-C1-10.data | Shape: (10000,)
#   Archivo: actions_E7-7-C11-20.data | Shape: (10000,)
#   Archivo: actions_E7-7-C21-40.data | Shape: (10000,)
#
# Revisando clave: 'output/Y'
#   Archivo: actions_E5-5-C1-10.data | Shape: (10000, 20)
#   Archivo: actions_E5-5-C11-20.data | Shape: (10000, 20)
#   Archivo: actions_E5-5-C21-40.data | Shape: (10000, 20)
#   Archivo: actions_E7-7-C1-10.data | Shape: (10000, 42)
#   Archivo: actions_E7-7-C11-20.data | Shape: (10000, 42)
#   Archivo: actions_E7-7-C21-40.data | Shape: (10000, 42)
#
# [ERROR CRÍTICO] Falló la concatenación en 'output/Y': all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 20 and the array at index 3 has size 42
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       4 data_files = ["actions_E5-5-C1-10.data", "actions_E5-5-C11-20.data", "actions_E5-5-C21-40.data",
#       5               "actions_E7-7-C1-10.data", "actions_E7-7-C11-20.data", "actions_E7-7-C21-40.data"]
#       6 output_name = "actions.data"
#       7
# ----> 8 generate_dataset(data_files, output_name)
#
# File ~/Escritorio/CPMP-Framework/src/preprocessing/dataset.py:30, in generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
#      28 """Helper para convertir datos a tensores de forma eficiente"""
#      29 if isinstance(val, np.ndarray):
# ---> 30     return torch.from_numpy(val)
#      31 return torch.tensor(val)
#
# File ~/Escritorio/CPMP-Framework/src/preprocessing/dataset.py:27, in generate_dataset(data_files, output_name, min_cost, max_cost, max_size)
#      24     self.output_datasets = {k: self.file[f'output/{k}'] for k in self.output_keys}
#      25     self.cost_dataset = self.file['C']
# ---> 27 def _to_tensor(self, val):
#      28     """Helper para convertir datos a tensores de forma eficiente"""
#      29     if isinstance(val, np.ndarray):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 20 and the array at index 3 has size 42

# %% [markdown]
# ## Generación de datos (RL)

# %%
## La generación de datos ocurre dentro del entrenamiento
## NO es necesario generarlos manualmente.

from generation.data import split_instances, generate_data_rl 
from generation.adapters.input import EnrichedLayoutAdapter, Layout4D3FAdapter
from generation.adapters.input.stack_features import StackFeatures3FAdapter
from generation.adapters.output import ActionAdapter
from training.training import load_model
from models.cpmp_transformer_v5 import CPMPTransformer

folders = ["E5-5-test"]
H = 7
max_steps = 50
input_adapter_config = (EnrichedLayoutAdapter, Layout4D3FAdapter, StackFeatures3FAdapter)
output_adapter_config = (ActionAdapter, )
model = load_model(CPMPTransformer, "best_v5")
batch_size = 32
num_workers = 12
output_name = "E5-5-test-rl.data"

# Divide las instancias en dos conjuntos (entrenamiento y validación)
# Asignamos el 80% para entrenamiento y el 20% para validación 
instance_files, _ = split_instances(folders, 0.80, 0.20, 42)

generate_data_rl(instance_files, H, max_steps, input_adapter_config, output_adapter_config, model, batch_size, num_workers, output_name)

# %%
## La generación de datos ocurre dentro del entrenamiento
## NO es necesario generarlos manualmente.

from generation.data import split_instances, generate_data_rl 
from generation.adapters.input import EnrichedLayoutAdapter, Layout4D3FAdapter
from generation.adapters.input.stack_features import StackFeatures3FAdapter
from generation.adapters.output import CostAdapter
from training.training import load_model
from models.cpmp_transformer_v5 import CPMPTransformer

folders = ["E5-5-R20", "E5-5-R50", "E5-5-R100", "E5-5-RFull"]

for folder in folders:
    H = 7
    max_steps = 50
    input_adapter_config = (EnrichedLayoutAdapter, Layout4D3FAdapter, StackFeatures3FAdapter)
    output_adapter_config = (CostAdapter, )
    model = load_model(CPMPTransformer, "best_rl")
    batch_size = 32
    num_workers = 12
    output_name = f"cost_{folder}.data"

    instance_files, _ = split_instances([folder], 1, 0, 42)
    instance_files = instance_files[:20000]

    generate_data_rl(instance_files, H, max_steps, input_adapter_config, output_adapter_config, model, batch_size, num_workers, output_name)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R20.data (Tamaño 19962)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R50.data (Tamaño 19999)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-R100.data (Tamaño 20000)
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/cost_E5-5-RFull.data (Tamaño 19828)
