# %%
# %load_ext autoreload
# %autoreload 2

# %%
from generation.instances import generate_instances

H = 7
S = 5
N = 25
amount = 1000

generate_instances("E5-25-1", H, S, N, amount)

# %%
from generation.data import generate_data

H = 7
max_steps = 50

generate_data("E5-25-1", H, max_steps)
# Out:
# Datos guardados en: /home/oscar/Escritorio/CPMP-Framework/data/E5-25-1.data
